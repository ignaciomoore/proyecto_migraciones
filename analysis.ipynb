# %%
import pandas as pd

# %%
df_activity = pd.read_csv("3_clean_datasets/activity_id.csv")
df_sex = pd.read_csv("3_clean_datasets/sex_id.csv")
df_studies = pd.read_csv("3_clean_datasets/studies_id.csv")
df_visa_type = pd.read_csv("3_clean_datasets/visa_type.csv")
df_comunas = pd.read_csv("3_clean_datasets/comunas_data.csv")
df_visas = pd.read_csv("3_clean_datasets/visas.csv")

# %%
df_visas.shape
df_comunas.shape
# Out:
# (348, 6)

# %%
df_comunas.head()
# Out:
#    region_id region_name  comuna_datachile_id  comuna_customs_id  \
# 0          1    Tarapacá                  226             1401.0
# 1          1    Tarapacá                  217             1405.0
# 2          1    Tarapacá                  113             1101.0
# 3          1    Tarapacá                  108             1404.0
# 4          1    Tarapacá                   58             1403.0
#
#    comuna_tax_office_id   comuna_name
# 0                1204.0  Pozo Almonte
# 1                1203.0          Pica
# 2                1201.0       Iquique
# 3                1206.0         Huara
# 4                1210.0      Colchane

# %%
df_comunas.head()
# Out:
#    comuna_datachile_id   comuna_name
# 0                  226  Pozo Almonte
# 1                  217          Pica
# 2                  113       Iquique
# 3                  108         Huara
# 4                   58      Colchane

# %%
df_visas.head()
# Out:
#    year  sex_id  birth_date  age  activity_id  studies_id  \
# 0  2005       1  1984-01-17   21            2           0
# 1  2005       1  1970-07-11   35            2           5
# 2  2005       2  1983-01-18   22            2           0
# 3  2005       2  1984-03-15   21            5           0
# 4  2005       1  1975-08-07   30            5           0
#
#    comuna_datachile_id  region_id country_name es_country_name  country_code  \
# 0                  290         13         Peru            Perú           219
# 1                  228         13      Bolivia         Bolivia           221
# 2                  228         13      Ecuador         Ecuador           218
# 3                  134         13      Morocco       Marruecos           128
# 4                  314          9        China           China           336
#
#   iso3    region  region_code       sub_region  sub_region_code  visa_type_id
# 0  PER  Americas           19    South America                5             1
# 1  BOL  Americas           19    South America                5             1
# 2  ECU  Americas           19    South America                5             1
# 3  MAR    Africa            2  Northern Africa               15             1
# 4  CHN      Asia          142     Eastern Asia               30             1
